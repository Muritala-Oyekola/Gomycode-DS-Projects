# %%
def my_function(name = 'Anonymous'):
  age = input(f'Hi {name} Enter your age:')
  print(f"May name is {name} and my age is {age}")

# %%
my_function('Muritala')
# Out:
# Hi Muritala Enter your age:48
# May name is Muritala and my age is 48

# %%
# \\\ As a python programmer in Aquarite company, create a function that creayes bottled water for companies.
# The bottled water should get the name of the company, how many litres that bottle can take, the colour of the cover,
#  the expriry date, the colour of the whole bottle.

def my_function(item = 'bottle'):
  company_name = input(f'Hello, Enter the company name')
  litres = input(f'Hello, Enter the litres')
  water_expiry = input(f'Hello, Enter the expiry date')
  bottle_cover  = input(f'Hello, Enter the bottle colour')
  print(f'The company name is {company_name} and the litres of the bottle is {litres}')
  print(f'The cover colour is {bottle_cover} and the expiry date is {water_expiry}')

# %%
my_function()
# Out:
# Hello, Enter the company nameAqual
# Hello, Enter the litres35CL
# Hello, Enter the expiry date31/12/2025
# Hello, Enter the bottle colouroff-white
# The company name is Aqual and the litres of the bottle is 35CL
# The cover colour is off-white and the expiry date is 31/12/2025

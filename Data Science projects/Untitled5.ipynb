# %%
Greeting = 'Hello Muritala!'
print(Greeting)
city = input('which city did you grow up?')
pet_name = input("what is your pet's name?")
print("name of the city and the pet's name")
print(f"(The city name is {city}, and the pet's name is {pet_name}")
print(f"The brand name is{city+pet_name}")
# Out:
# Hello Muritala!
# which city did you grow up?Lagos
# what is your pet's name?Bush
# name of the city and the pet's name
# (The city name is Lagos, and the pet's name is Bush
# The brand name isLagosBush

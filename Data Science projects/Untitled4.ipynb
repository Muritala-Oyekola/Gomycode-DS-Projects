# %%
order_total = 15
customer_membership = True


if order_total >100 and customer_membership == True:
  print('Discount apply.')
else:
  print('Discount not apply.')
# Out:
# Discount not apply.

# %%
order_total = 75
customer_location = "USA"

if order_total >= 50 or customer_location == "USA":
    print("Free shipping applied.")
else:
    print("Shipping fee applied.")
# Out:
# Free shipping applied.

# %%
is_member = False

if not is_member:
    print("Customer is not a member.")
else:
    print("Customer is a member.")
# Out:
# Customer is not a member.

# %%
x = (2>5) == (3==6)
if x :
    print('x is True')
else:
    prin('x is not True')
# Out:
# x is True

# %%
x=19
if x < 10:
    print ("Good morning")
elif x<12:
    print ("Soon time for lunch")
elif x<18:
    print ("Good day")
elif x<22:
    print ("Good evening")
else:
    print ("Good night")
# Out:
# Good evening

# %%
l=[9, 13, 2]
for i in l:
print(i)
# Out:
#   File "<ipython-input-22-748a6e1116c2>", line 3
#     print(i)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
max_age = 90
current_age = int(input('what is you age'))
remain = max_age - current_age
# Out:
# what is you age70

# %%
days_left = remain * 365

# %%
Weeks_left = remain * 52

# %%
months_left = remain * 12

# %%
print(f"Hello, you have {days_left} days, {weeks_left} weeks, {months_left} months")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-96ae9474e2bd> in <cell line: 1>()
# ----> 1 print(f"Hello, you have {days_left} days, {weeks_left} weeks, {months_left} months")
#
# NameError: name 'weeks_left' is not defined

# %%
print(f"Hello, you have {days_left} days, {weeks_left} weeks, {months_left} months")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-96ae9474e2bd> in <cell line: 1>()
# ----> 1 print(f"Hello, you have {days_left} days, {weeks_left} weeks, {months_left} months")
#
# NameError: name 'weeks_left' is not defined

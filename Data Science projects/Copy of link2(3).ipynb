# %%
import numpy as np

array_a = np.array([7,8,9])
array_a
# Out:
# array([7, 8, 9])

# %%
array_b = np.array([[1,2,3],[4,5,6]])
array_b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
array_b * 2
# Out:
# array([[ 2,  4,  6],
#        [ 8, 10, 12]])

# %%
list_a = [1,2,3]
list_a +[2]
# Out:
# [1, 2, 3, 2]

# %%
list_a = [1,2,3]
list_a +[2,4]
# Out:
# [1, 2, 3, 2, 4]

# %%
import numpy as np
array_a = np.array([7,8,9])
array_a
# Out:
# array([7, 8, 9])

# %%
array_b = np.array([[1,2,3],[4,5,6]])
array_b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
array_b[1]
# Out:
# array([4, 5, 6])

# %%
array_a * array_b
# Out:
# array([[ 7, 16, 27],
#        [28, 40, 54]])

# %%
array_b - array_a
# Out:
# array([[-6, -6, -6],
#        [-3, -3, -3]])

# %%
a = np.array([[1,2,3],[3,4,5]])
b = np.array([[2,3,3],[9,5,2]])

# %%
a
# Out:
# array([[1, 2, 3],
#        [3, 4, 5]])

# %%
b
# Out:
# array([[2, 3, 3],
#        [9, 5, 2]])

# %%
a * b
# Out:
# array([[ 2,  6,  9],
#        [27, 20, 10]])

# %%
a.shape
# Out:
# (2, 3)

# %%
b.shape
# Out:
# (2, 3)

# %%
a/b
# Out:
# array([[0.5       , 0.66666667, 1.        ],
#        [0.33333333, 0.8       , 2.5       ]])

# %%
a + b
# Out:
# array([[ 3,  5,  6],
#        [12,  9,  7]])

# %%
np.add(a,b)
# Out:
# array([[ 4,  6,  6],
#        [18, 10,  4]])

# %%
np.divide(a,b)
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.multiply(a,b)
# Out:
# array([[ 4,  9,  9],
#        [81, 25,  4]])

# %%
np.subtract(a,b)
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
a.shape,b.shape
# Out:
# ((2, 3), (2, 3))

# %%
b=b.reshape(3,2)
b
# Out:
# array([[2, 3],
#        [3, 9],
#        [5, 2]])

# %%
np.matmul(a,b)
# Out:
# array([[28, 39],
#        [43, 76]])

# %%
patient = input('Name of the patient')
patient = input('Your age patient')
patient = input('You are new in the hospital')

print(patient 'my name is {}, I am {} age and I am new in the {}' format(Name, age and hospital))
# Out:
#   File "<ipython-input-5-2f463819eaf5>", line 5
#     print(patient 'my name is {}, I am {} age and I am new in the {}' format(Name, age and hospital))
#                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

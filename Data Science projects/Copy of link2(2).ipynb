# %%
import numpy as np

array_a = np.array([7,8,9])
array_a
# Out:
# array([7, 8, 9])

# %%
array_b = np.array([[1,2,3],[4,5,6]])
array_b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
array_b * 2
# Out:
# array([[ 2,  4,  6],
#        [ 8, 10, 12]])

# %%
list_a = [1,2,3]
list_a +[2]
# Out:
# [1, 2, 3, 2]

# %%
list_a = [1,2,3]
list_a +[2,4]
# Out:
# [1, 2, 3, 2, 4]

# %%
import numpy as np
array_a = np.array([7,8,9])
array_a
# Out:
# array([7, 8, 9])

# %%
array_b = np.array([[1,2,3],[4,5,6]])
array_b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
array_b[1]
# Out:
# array([4, 5, 6])

# %%
array_a * array_b
# Out:
# array([[ 7, 16, 27],
#        [28, 40, 54]])

# %%
array_b - array_a
# Out:
# array([[-6, -6, -6],
#        [-3, -3, -3]])

# %%
a = np.array([[1,2,3],[3,4,5]])
b = np.array([[2,3,3],[9,5,2]])

# %%
a
# Out:
# array([[1, 2, 3],
#        [3, 4, 5]])

# %%
b
# Out:
# array([[2, 3, 3],
#        [9, 5, 2]])

# %%
a * b
# Out:
# array([[ 2,  6,  9],
#        [27, 20, 10]])
